# %%
from sklearn.neighbors import KNeighborsClassifier

# 데이터 준비
fish_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
fish_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]
fish_data = [[l, w] for l, w in zip(fish_length, fish_weight)]
fish_target = [1] * 35 + [0] * 14

# K-NN 모델 훈련 (여기서는 K=5로 설정)
kn = KNeighborsClassifier(n_neighbors=5)
kn.fit(fish_data, fish_target)
print("모델 훈련 완료")
# Out:
# 모델 훈련 완료

# %%
import matplotlib.pyplot as plt

# 데이터 준비
fish_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
fish_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]
fish_target = [1] * 35 + [0] * 14

# 도미와 빙어 데이터 분리
bream_data = [[fish_length[i], fish_weight[i]] for i in range(len(fish_target)) if fish_target[i] == 1]
smelt_data = [[fish_length[i], fish_weight[i]] for i in range(len(fish_target)) if fish_target[i] == 0]
bream_length, bream_weight = zip(*bream_data)
smelt_length, smelt_weight = zip(*smelt_data)

# 산점도 그리기
plt.scatter(bream_length, bream_weight, label='도미(Bream)', color='red')
plt.scatter(smelt_length, smelt_weight, label='빙어(Smelt)', color='blue')
plt.xlabel('길이 (cm)')
plt.ylabel('무게 (g)')
plt.title('도미와 빙어 데이터')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44172 (\N{HANGUL SYLLABLE GE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50752 (\N{HANGUL SYLLABLE WA}) missing from font(s) DejaVu Sans.
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# 1. 데이터 준비
fish_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
fish_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]
fish_data = [[l, w] for l, w in zip(fish_length, fish_weight)]
fish_target = [1] * 35 + [0] * 14

# 2. K-NN 모델 훈련
kn = KNeighborsClassifier(n_neighbors=5)
kn.fit(fish_data, fish_target)

# 새로운 테스트 데이터
new_test_data = [30, 600]

# 3. 예측 및 가장 가까운 이웃 찾기
prediction = kn.predict([new_test_data])
distances, indexes = kn.kneighbors([new_test_data])

# 결과 출력
print("--- K-NN 예측 결과 ---")
print(f"새로운 물고기 ({new_test_data[0]}cm, {new_test_data[1]}g)의 예측: {'도미' if prediction[0] == 1 else '빙어'}")
print(f"가장 가까운 5개 이웃의 인덱스: {indexes[0]}")
print(f"가장 가까운 5개 이웃의 데이터: {[fish_data[i] for i in indexes[0]]}")
print(f"가장 가까운 5개 이웃의 종류: {[('도미' if fish_target[i] == 1 else '빙어') for i in indexes[0]]}")

# 4. 데이터 시각화
plt.figure(figsize=(10, 6))

# 도미와 빙어 데이터 분리
bream_data = [fish_data[i] for i in range(len(fish_target)) if fish_target[i] == 1]
smelt_data = [fish_data[i] for i in range(len(fish_target)) if fish_target[i] == 0]
bream_length, bream_weight = zip(*bream_data)
smelt_length, smelt_weight = zip(*smelt_data)

# 산점도 그리기
plt.scatter(bream_length, bream_weight, label='도미(Bream)', color='red', alpha=0.7)
plt.scatter(smelt_length, smelt_weight, label='빙어(Smelt)', color='blue', alpha=0.7)
plt.scatter(new_test_data[0], new_test_data[1], label='새로운 물고기', color='green', marker='^', s=150, edgecolor='black', zorder=5) # 새로운 데이터

# 가장 가까운 이웃들을 원으로 표시
for i in indexes[0]:
    plt.scatter(fish_data[i][0], fish_data[i][1], color='purple', marker='o', s=100, facecolors='none', edgecolor='purple', linewidths=2, zorder=4)

plt.xlabel('길이 (cm)', fontsize=12)
plt.ylabel('무게 (g)', fontsize=12)
plt.title('K-NN 이웃을 시각화한 물고기 분류', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- K-NN 예측 결과 ---
# 새로운 물고기 (30cm, 600g)의 예측: 도미
# 가장 가까운 5개 이웃의 인덱스: [15 14 18 22 20]
# 가장 가까운 5개 이웃의 데이터: [[32.0, 600.0], [32.0, 600.0], [33.5, 610.0], [34.5, 620.0], [34.0, 575.0]]
# 가장 가까운 5개 이웃의 종류: ['도미', '도미', '도미', '도미', '도미']
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44172 (\N{HANGUL SYLLABLE GE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# 물고기 길이와 무게 데이터
fish_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
fish_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# 타깃 데이터: 도미(1) 35마리, 빙어(0) 14마리
fish_target = [1] * 35 + [0] * 14

# 길이와 무게를 (길이, 무게) 형태로 묶어 데이터 생성
fish_data = [[l, w] for l, w in zip(fish_length, fish_weight)]

# 새로운 테스트 데이터
new_test_data = [30, 600]

# 도미와 빙어 데이터 분리 (시각화용)
bream_data = [fish_data[i] for i in range(len(fish_target)) if fish_target[i] == 1]
smelt_data = [fish_data[i] for i in range(len(fish_target)) if fish_target[i] == 0]
bream_length, bream_weight = zip(*bream_data)
smelt_length, smelt_weight = zip(*smelt_data)

# K-NN 모델 훈련
kn = KNeighborsClassifier(n_neighbors=5)
kn.fit(fish_data, fish_target)

# 새로운 데이터에 대한 예측 및 이웃 찾기
prediction = kn.predict([new_test_data])
distances, indexes = kn.kneighbors([new_test_data])

# 시각화
plt.figure(figsize=(10, 6))
plt.scatter(bream_length, bream_weight, label='도미(Bream)', color='red', alpha=0.7)
plt.scatter(smelt_length, smelt_weight, label='빙어(Smelt)', color='blue', alpha=0.7)
plt.scatter(new_test_data[0], new_test_data[1], label='새로운 물고기', color='green', marker='^', s=150, edgecolor='black', zorder=5)

# 가장 가까운 5개 이웃을 표시
for i in indexes[0]:
    plt.scatter(fish_data[i][0], fish_data[i][1], color='purple', marker='o', s=100, facecolors='none', edgecolor='purple', linewidths=2, zorder=4)

plt.xlabel('길이 (cm)', fontsize=12)
plt.ylabel('무게 (g)', fontsize=12)
plt.title('K-NN 이웃을 시각화한 물고기 분류', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# 결과 출력
print("--- K-NN 예측 결과 ---")
print(f"새로운 물고기 ({new_test_data[0]}cm, {new_test_data[1]}g)의 예측: {'도미' if prediction[0] == 1 else '빙어'}")
print(f"가장 가까운 5개 이웃의 인덱스: {indexes[0]}")
print(f"가장 가까운 5개 이웃의 데이터: {[fish_data[i] for i in indexes[0]]}")
print(f"가장 가까운 5개 이웃의 종류: {[('도미' if fish_target[i] == 1 else '빙어') for i in indexes[0]]}")
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44172 (\N{HANGUL SYLLABLE GE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50883 (\N{HANGUL SYLLABLE US}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51012 (\N{HANGUL SYLLABLE EUL}) missing from font(s) DejaVu Sans.
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np

# 1. 데이터 준비
fish_length = np.array([25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                         31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                         35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                         10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0])
fish_weight = np.array([242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                         500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                         700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                         7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9])
fish_data = np.column_stack((fish_length, fish_weight))
fish_target = np.array([1] * 35 + [0] * 14)

# 2. 데이터 표준화 (특성 스케일링)
scaler = StandardScaler()
scaler.fit(fish_data)
scaled_data = scaler.transform(fish_data)

# 새로운 테스트 데이터도 표준화
new_test_data = np.array([[30, 600]])
scaled_new_data = scaler.transform(new_test_data)

# 3. K-NN 모델 훈련 (표준화된 데이터 사용)
kn = KNeighborsClassifier(n_neighbors=5)
kn.fit(scaled_data, fish_target)

# 4. 예측 및 가장 가까운 이웃 찾기
prediction = kn.predict(scaled_new_data)
distances, indexes = kn.kneighbors(scaled_new_data)

# 결과 출력
print("--- K-NN 예측 결과 (표준화 후) ---")
print(f"새로운 물고기 ({new_test_data[0][0]}cm, {new_test_data[0][1]}g)의 예측: {'도미' if prediction[0] == 1 else '빙어'}")
print(f"가장 가까운 5개 이웃의 인덱스: {indexes[0]}")
print(f"가장 가까운 5개 이웃의 데이터 (표준화 전): {[fish_data[i] for i in indexes[0]]}")
print(f"가장 가까운 5개 이웃의 종류: {[('도미' if fish_target[i] == 1 else '빙어') for i in indexes[0]]}")

# 5. 데이터 시각화 (표준화된 데이터 사용)
plt.figure(figsize=(10, 6))

# 도미와 빙어 데이터 분리
scaled_bream_data = scaled_data[fish_target == 1]
scaled_smelt_data = scaled_data[fish_target == 0]

plt.scatter(scaled_bream_data[:, 0], scaled_bream_data[:, 1], label='도미(Bream)', color='red', alpha=0.7)
plt.scatter(scaled_smelt_data[:, 0], scaled_smelt_data[:, 1], label='빙어(Smelt)', color='blue', alpha=0.7)
plt.scatter(scaled_new_data[:, 0], scaled_new_data[:, 1], label='새로운 물고기', color='green', marker='^', s=150, edgecolor='black', zorder=5)

# 가장 가까운 이웃들을 원으로 표시
for i in indexes[0]:
    plt.scatter(scaled_data[i, 0], scaled_data[i, 1], color='purple', marker='o', s=100, facecolors='none', edgecolor='purple', linewidths=2, zorder=4)

plt.xlabel('길이 (표준화)', fontsize=12)
plt.ylabel('무게 (표준화)', fontsize=12)
plt.title('K-NN 이웃을 시각화한 물고기 분류 (데이터 표준화)', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- K-NN 예측 결과 (표준화 후) ---
# 새로운 물고기 (30cm, 600g)의 예측: 도미
# 가장 가까운 5개 이웃의 인덱스: [15 14  6  9 11]
# 가장 가까운 5개 이웃의 데이터 (표준화 전): [array([ 32., 600.]), array([ 32., 600.]), array([ 29.7, 500. ]), array([ 30.7, 500. ]), array([ 31., 500.])]
# 가장 가까운 5개 이웃의 종류: ['도미', '도미', '도미', '도미', '도미']
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44172 (\N{HANGUL SYLLABLE GE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np

# 1. 데이터 준비
fish_length = np.array([25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                         31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                         35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                         10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0])
fish_weight = np.array([242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                         500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                         700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                         7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9])
fish_data = np.column_stack((fish_length, fish_weight))
fish_target = np.array([1] * 35 + [0] * 14)

# 2. 데이터 표준화 (Standardization)
scaler = StandardScaler()
scaler.fit(fish_data)
scaled_data = scaler.transform(fish_data)

# 새로운 테스트 데이터도 표준화
new_test_data = np.array([[30, 600]])
scaled_new_data = scaler.transform(new_test_data)

# 3. K-NN 모델 훈련 (표준화된 데이터 사용)
kn = KNeighborsClassifier(n_neighbors=5)
kn.fit(scaled_data, fish_target)

# 4. 예측 및 가장 가까운 이웃 찾기
prediction = kn.predict(scaled_new_data)
distances, indexes = kn.kneighbors(scaled_new_data)

# 결과 출력
print("--- K-NN 예측 결과 (표준화 후) ---")
print(f"새로운 물고기 ({new_test_data[0][0]}cm, {new_test_data[0][1]}g)의 예측: {'도미' if prediction[0] == 1 else '빙어'}")
print(f"가장 가까운 5개 이웃의 인덱스: {indexes[0]}")
print(f"가장 가까운 5개 이웃의 데이터 (표준화 전): {[fish_data[i] for i in indexes[0]]}")
print(f"가장 가까운 5개 이웃의 종류: {[('도미' if fish_target[i] == 1 else '빙어') for i in indexes[0]]}")

# 5. 데이터 시각화 (표준화된 데이터 사용)
plt.figure(figsize=(10, 6))

# 도미와 빙어 데이터 분리
scaled_bream_data = scaled_data[fish_target == 1]
scaled_smelt_data = scaled_data[fish_target == 0]

plt.scatter(scaled_bream_data[:, 0], scaled_bream_data[:, 1], label='도미(Bream)', color='red', alpha=0.7)
plt.scatter(scaled_smelt_data[:, 0], scaled_smelt_data[:, 1], label='빙어(Smelt)', color='blue', alpha=0.7)
plt.scatter(scaled_new_data[:, 0], scaled_new_data[:, 1], label='new data', color='green', marker='^', s=150, edgecolor='black', zorder=5)

# 가장 가까운 이웃들을 원으로 표시
for i in indexes[0]:
    plt.scatter(scaled_data[i, 0], scaled_data[i, 1], color='purple', marker='o', s=100, facecolors='none', edgecolor='purple', linewidths=2, zorder=4)

plt.xlabel('길이 (표준화)', fontsize=12)
plt.ylabel('무게 (표준화)', fontsize=12)
plt.title('K-NN 이웃을 시각화한 물고기 분류 (데이터 표준화)', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- K-NN 예측 결과 (표준화 후) ---
# 새로운 물고기 (30cm, 600g)의 예측: 도미
# 가장 가까운 5개 이웃의 인덱스: [15 14  6  9 11]
# 가장 가까운 5개 이웃의 데이터 (표준화 전): [array([ 32., 600.]), array([ 32., 600.]), array([ 29.7, 500. ]), array([ 30.7, 500. ]), array([ 31., 500.])]
# 가장 가까운 5개 이웃의 종류: ['도미', '도미', '도미', '도미', '도미']
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44172 (\N{HANGUL SYLLABLE GE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np

# 1. 데이터 준비
fish_length = np.array([25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                         31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                         35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                         10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0])
fish_weight = np.array([242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                         500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                         700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                         7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9])
fish_data = np.column_stack((fish_length, fish_weight))
fish_target = np.array([1] * 35 + [0] * 14)

# 2. 데이터 표준화 (Standardization)
scaler = StandardScaler()
scaler.fit(fish_data)
scaled_data = scaler.transform(fish_data)

# 새로운 테스트 데이터도 표준화
new_test_data = np.array([[30, 600]])
scaled_new_data = scaler.transform(new_test_data)

# 3. K-NN 모델 훈련 (표준화된 데이터 사용)
kn = KNeighborsClassifier(n_neighbors=5)
kn.fit(scaled_data, fish_target)

# 4. 예측 및 가장 가까운 이웃 찾기
prediction = kn.predict(scaled_new_data)
distances, indexes = kn.kneighbors(scaled_new_data)

# 결과 출력
print("--- K-NN 예측 결과 (데이터 표준화 후) ---")
print(f"새로운 물고기 ({new_test_data[0][0]}cm, {new_test_data[0][1]}g)의 예측: {'도미' if prediction[0] == 1 else '빙어'}")
print(f"가장 가까운 5개 이웃의 인덱스: {indexes[0]}")
print(f"가장 가까운 5개 이웃의 데이터 (표준화 전): {[fish_data[i] for i in indexes[0]]}")
print(f"가장 가까운 5개 이웃의 종류: {[('도미' if fish_target[i] == 1 else '빙어') for i in indexes[0]]}")

# 5. 데이터 시각화 (표준화된 데이터 사용)
plt.figure(figsize=(10, 6))

# 도미와 빙어 데이터 분리
scaled_bream_data = scaled_data[fish_target == 1]
scaled_smelt_data = scaled_data[fish_target == 0]

plt.scatter(scaled_bream_data[:, 0], scaled_bream_data[:, 1], label='도미(Bream)', color='red', alpha=0.7)
plt.scatter(scaled_smelt_data[:, 0], scaled_smelt_data[:, 1], label='빙어(Smelt)', color='blue', alpha=0.7)
plt.scatter(scaled_new_data[:, 0], scaled_new_data[:, 1], label='new data', color='green', marker='^', s=150, edgecolor='black', zorder=5)

# 가장 가까운 이웃들을 원으로 표시
for i in indexes[0]:
    plt.scatter(scaled_data[i, 0], scaled_data[i, 1], color='purple', marker='o', s=100, facecolors='none', edgecolor='purple', linewidths=2, zorder=4)

plt.xlabel('길이 (표준화)', fontsize=12)
plt.ylabel('무게 (표준화)', fontsize=12)
plt.title('K-NN 이웃을 시각화한 물고기 분류 (데이터 표준화)', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- K-NN 예측 결과 (데이터 표준화 후) ---
# 새로운 물고기 (30cm, 600g)의 예측: 도미
# 가장 가까운 5개 이웃의 인덱스: [15 14  6  9 11]
# 가장 가까운 5개 이웃의 데이터 (표준화 전): [array([ 32., 600.]), array([ 32., 600.]), array([ 29.7, 500. ]), array([ 30.7, 500. ]), array([ 31., 500.])]
# 가장 가까운 5개 이웃의 종류: ['도미', '도미', '도미', '도미', '도미']
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44172 (\N{HANGUL SYLLABLE GE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54364 (\N{HANGUL SYLLABLE PYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np

# 1. 데이터 준비
fish_length = np.array([25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                         31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                         35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                         10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0])
fish_weight = np.array([242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                         500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                         700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                         7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9])
fish_data = np.column_stack((fish_length, fish_weight))
fish_target = np.array([1] * 35 + [0] * 14)

# 2. 데이터 표준화 (Standardization)
scaler = StandardScaler()
scaler.fit(fish_data)
scaled_data = scaler.transform(fish_data)

# 새로운 테스트 데이터도 표준화
new_test_data = np.array([[30, 600]])
scaled_new_data = scaler.transform(new_test_data)

# 3. K-NN 모델 훈련 (표준화된 데이터 사용)
kn = KNeighborsClassifier(n_neighbors=5)
kn.fit(scaled_data, fish_target)

# 4. 예측 및 가장 가까운 이웃 찾기
prediction = kn.predict(scaled_new_data)
distances, indexes = kn.kneighbors(scaled_new_data)

# 결과 출력
print("--- K-NN 예측 결과 (데이터 표준화 후) ---")
print(f"새로운 물고기 ({new_test_data[0][0]}cm, {new_test_data[0][1]}g)의 예측: {'도미' if prediction[0] == 1 else '빙어'}")
print(f"가장 가까운 5개 이웃의 인덱스: {indexes[0]}")
print(f"가장 가까운 5개 이웃의 데이터 (표준화 전): {[fish_data[i] for i in indexes[0]]}")
print(f"가장 가까운 5개 이웃의 종류: {[('도미' if fish_target[i] == 1 else '빙어') for i in indexes[0]]}")

# 5. 데이터 시각화 (표준화된 데이터 사용)
plt.figure(figsize=(10, 6))

# 도미와 빙어 데이터 분리
scaled_bream_data = scaled_data[fish_target == 1]
scaled_smelt_data = scaled_data[fish_target == 0]

plt.scatter(scaled_bream_data[:, 0], scaled_bream_data[:, 1], label='도미(Bream)', color='red', alpha=0.7)
plt.scatter(scaled_smelt_data[:, 0], scaled_smelt_data[:, 1], label='빙어(Smelt)', color='blue', alpha=0.7)
plt.scatter(scaled_new_data[:, 0], scaled_new_data[:, 1], label='new data', color='green', marker='^', s=150, edgecolor='black', zorder=5)

# 가장 가까운 이웃들을 원으로 표시
for i in indexes[0]:
    plt.scatter(scaled_data[i, 0], scaled_data[i, 1], color='purple', marker='o', s=100, facecolors='none', edgecolor='purple', linewidths=2, zorder=4)

plt.xlabel('length (cm)', fontsize=12)
plt.ylabel('weight (g)', fontsize=12)
plt.title('K-NN 이웃을 시각화한 물고기 분류 (데이터 표준화)', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- K-NN 예측 결과 (데이터 표준화 후) ---
# 새로운 물고기 (30cm, 600g)의 예측: 도미
# 가장 가까운 5개 이웃의 인덱스: [15 14  6  9 11]
# 가장 가까운 5개 이웃의 데이터 (표준화 전): [array([ 32., 600.]), array([ 32., 600.]), array([ 29.7, 500. ]), array([ 30.7, 500. ]), array([ 31., 500.])]
# 가장 가까운 5개 이웃의 종류: ['도미', '도미', '도미', '도미', '도미']
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50883 (\N{HANGUL SYLLABLE US}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51012 (\N{HANGUL SYLLABLE EUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np

# 1. 데이터 준비
fish_length = np.array([25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                         31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                         35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8,
                         10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0])
fish_weight = np.array([242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                         500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                         700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7,
                         7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9])
fish_data = np.column_stack((fish_length, fish_weight))
fish_target = np.array([1] * 35 + [0] * 14)

# 2. 데이터 표준화 (Standardization) - 모델 훈련용
scaler = StandardScaler()
scaler.fit(fish_data)
scaled_data = scaler.transform(fish_data)

# 새로운 테스트 데이터도 표준화
new_test_data = np.array([[30, 600]])
scaled_new_data = scaler.transform(new_test_data)

# 3. K-NN 모델 훈련 (표준화된 데이터 사용)
kn = KNeighborsClassifier(n_neighbors=5)
kn.fit(scaled_data, fish_target)

# 4. 예측 및 가장 가까운 이웃 찾기
prediction = kn.predict(scaled_new_data)
distances, indexes = kn.kneighbors(scaled_new_data)

# 결과 출력
print("--- K-NN 예측 결과 (데이터 표준화 후) ---")
print(f"새로운 물고기 ({new_test_data[0][0]}cm, {new_test_data[0][1]}g)의 예측: {'도미' if prediction[0] == 1 else '빙어'}")
print(f"가장 가까운 5개 이웃의 인덱스: {indexes[0]}")
print(f"가장 가까운 5개 이웃의 데이터 (표준화 전): {[fish_data[i] for i in indexes[0]]}")
print(f"가장 가까운 5개 이웃의 종류: {[('도미' if fish_target[i] == 1 else '빙어') for i in indexes[0]]}")

# 5. 데이터 시각화 (원본 단위 사용)
plt.figure(figsize=(10, 6))

# 도미와 빙어 데이터 분리
bream_data = fish_data[fish_target == 1]
smelt_data = fish_data[fish_target == 0]

plt.scatter(bream_data[:, 0], bream_data[:, 1], label='도미(Bream)', color='red', alpha=0.7)
plt.scatter(smelt_data[:, 0], smelt_data[:, 1], label='빙어(Smelt)', color='blue', alpha=0.7)
plt.scatter(new_test_data[:, 0], new_test_data[:, 1], label='new data', color='green', marker='^', s=150, edgecolor='black', zorder=5)

# 가장 가까운 이웃들을 원으로 표시 (원본 데이터 사용)
for i in indexes[0]:
    plt.scatter(fish_data[i, 0], fish_data[i, 1], color='purple', marker='o', s=100, facecolors='none', edgecolor='purple', linewidths=2, zorder=4)

plt.xlabel('길이 (cm)', fontsize=12)
plt.ylabel('무게 (g)', fontsize=12)
plt.title('K-NN 이웃을 시각화한 물고기 분류', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# --- K-NN 예측 결과 (데이터 표준화 후) ---
# 새로운 물고기 (30cm, 600g)의 예측: 도미
# 가장 가까운 5개 이웃의 인덱스: [15 14  6  9 11]
# 가장 가까운 5개 이웃의 데이터 (표준화 전): [array([ 32., 600.]), array([ 32., 600.]), array([ 29.7, 500. ]), array([ 30.7, 500. ]), array([ 31., 500.])]
# 가장 가까운 5개 이웃의 종류: ['도미', '도미', '도미', '도미', '도미']
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44172 (\N{HANGUL SYLLABLE GE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
